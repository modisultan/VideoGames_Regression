# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# %%
url = "https://www.imdb.com/search/title/?title_type=video_game&num_votes=,5000,&sort=user_rating,desc&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=87cca6a7-a16d-42d9-b9de-6aace99ec40a&pf_rd_r=ERFX36S273PQKZHMN3NF&pf_rd_s=center-6&pf_rd_t=60601&pf_rd_i=video-games&ref_=fea_vg_scg_ats_toprated_hd"

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
soup.find('div',class_='lister-item mode-advanced')
# Out:
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt5667286"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt5667286/"> <img alt="Wiedzmin 3: Dziki Gon Krew i wino" class="loadlate" data-tconst="tt5667286" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTg2ZmY0MGUtZmFjZS00YjkxLTlmMWEtMDE0ZWQwYzBlODA2XkEyXkFqcGdeQXVyMzUwNzgzNzg@._V1_UY98_CR5,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt5667286/">Wiedzmin 3: Dziki Gon Krew i wino</a>
# <span class="lister-item-year text-muted unbold">(2016 Video Game)</span>
# </h3>
# <p class="text-muted">
# <span class="genre">
# Action, Adventure, Drama            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="9.8" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>9.8</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt5667286" id="urv_tt5667286">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt5667286">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt5667286|imdb|9.8|9.8|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 9.8/10 (6,810 votes) - click stars to rate">
# <meta content="9.8" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="6810" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 137.2px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">9.8</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt5667286/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# </div>
# <p class="text-muted">
# Geralt is in the southern province of Toussaint where a monstrous serial killer is targeting knights with a dark past. Geralt and his old vampire friend investigate the killer's motives.</p>
# <p class="">
#     Director:
# <a href="/name/nm2840922/">Konrad Tomaszkiewicz</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0168339/">Doug Cockle</a>,
# <a href="/name/nm1769728/">MyAnna Buring</a>,
# <a href="/name/nm1553405/">Antonia Bernath</a>,
# <a href="/name/nm1646345/">Mark Noble</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="6810" name="nv">6,810</span>
# </p>
# </div>
# </div>

# %%
title = soup.find('h3',class_="lister-item-header").a.text
title
# Out:
# 'Wiedzmin 3: Dziki Gon Krew i wino'

# %%
year = soup.find('span',class_="lister-item-year text-muted unbold").text.replace('(','').replace(')','')
year
# Out:
# '2016 Video Game'

# %%
Gtype = soup.find('p',class_="text-muted").text.strip()
Gtype
# Out:
# 'Action, Adventure, Drama'

# %%
rate = soup.find('div',class_="ratings-bar").find('strong').text
rate
# Out:
# '9.8'

# %%
descr = soup.find_all('p',class_="text-muted")[1].text.strip()
descr
# Out:
# "Geralt is in the southern province of Toussaint where a monstrous serial killer is targeting knights with a dark past. Geralt and his old vampire friend investigate the killer's motives."

# %%
votes = soup.find('p',class_='sort-num_votes-visible').text.split()[1].replace(',','')
votes
# Out:
# '6810'

# %%
def clean_num(s):
    """cleans text scraped from website
    
    Parameters:
    s (String): raw text

    Returns:
    String: cleaned digit text

    """ 

    if s is None:
        return s
    return "".join(re.findall('\d*\.?\d+',s))

def get_data(block, tag, class_text):
    """fetch data from tag and its associated class
    
    Parameters:
    block (int): Book item 
    tag (String): tag for element we want to fetch
    class_text (String): class for element we want to fetch

    Returns:
    String: data text fetched

    """ 
    try:
        return block.find(tag, class_ = class_text).text.replace('(','').replace(')','')
    except AttributeError:
        return ""
    return

def get_data_a_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).a.text
    except AttributeError:
        return ""
    return
def get_data_strong_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).strong.text
    except AttributeError:
        return ""
    return
def get_data_descr(i, tag, class_text):    
    try:
        return i.find_all(tag, class_ = class_text)[1].text.strip()
    except AttributeError:
        return ""
    return


def get_data_votes(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).text.split()[1].replace(',','')
    except AttributeError:
        return ""
    return

# %%
#Test with the first videio game to ensure functions are working
for i in (soup.find_all('div','lister-item mode-advanced')):
    print(get_data_a_tag(i, "h3","lister-item-header"))
    print(get_data(i, "span", "lister-item-year text-muted unbold"))
    print(get_data(i, "p", "text-muted").strip())
    print(clean_num(get_data_strong_tag(i, "div","ratings-bar")))
    print(get_data_descr(i, "p","text-muted"))
    print(clean_num(get_data_votes(i, "p","sort-num_votes-visible")))
# Out:
# Wiedzmin 3: Dziki Gon Krew i wino
# 2016 Video Game
# Action, Adventure, Drama
# 9.8
# Geralt is in the southern province of Toussaint where a monstrous serial killer is targeting knights with a dark past. Geralt and his old vampire friend investigate the killer's motives.
# 6810
# Red Dead Redemption II
# 2018 Video Game
# Action, Adventure, Crime
# 9.7
# Amidst the decline of the Wild West at the turn of the 20th century, outlaw Arthur Morgan and his gang struggle to cope with the loss of their way of life.
# 28686
# Wiedzmin 3: Dziki Gon
# 2015 Video Game
# banned
# |
#
# Action, Adventure, Drama
# 9.7
# A monster hunter for hire embarks on an epic journey to find his former apprentice before The Wild Hunt can capture her and bring about the destruction of the world.
# 23029
# The Last of Us
# 2013 Video Game
# Action, Adventure, Drama
# 9.7
# In a hostile, post-pandemic world, Joel and Ellie, brought together by desperate circumstances, must rely on each other to survive a brutal journey across what remains of the United States.
# 55702
# Mass Effect: Legendary Edition
# 2021 Video Game
# Sci-Fi
# 9.7
# A compilation of the first three Mass Effect games.
# 706
# God of War
# 2018 Video Game
# Action, Adventure, Drama
# 9.6
# After wiping out the gods of Mount Olympus, Kratos moves on to the frigid lands of Scandinavia, where he and his son must embark on an odyssey across a dangerous world of gods and monsters.
# 21310
# Perusona 5: Za roiyaru
# 2019 Video Game
# Action, Adventure, Fantasy
# 9.6
# A group of high school students create a vigilante group to expose the crimes of corrupt adults but soon find themselves in the midst of a worldwide conspiracy and targeted by powerful individuals who would do anything to silence them.
# 798
# Zeruda no densetsu: Toki no okarina
# 1998 Video Game
# Action, Adventure, Fantasy
# 9.6
# A young Kokiri boy discovers that his destiny is to free the Seven Sages and save the land of Hyrule from the treacherous sorcerer Ganondorf.
# 8998
# Metal Gear Solid
# 1998 Video Game
# Action, Adventure, Drama
# 9.6
# A crack government anti-terrorist squad takes over an obscure Alaskan nuclear disposal facility. Solid Snake is up for the task to infiltrate the facility, rescue the two hostages and thwart the terrorists' plans.
# 11329
# Wiedzmin 3: Dziki Gon - Serca z kamienia
# 2015 Video Game
# Action, Adventure, Drama
# 9.5
# Geralt is forced by a seemingly harmless merchant with sinister powers to complete three difficult tasks for a bored immortal, once a troubled nobleman who made a deal with the devil.
# 5679
# Uncharted 4: A Thief's End
# 2016 Video Game
# Action, Adventure, Drama
# 9.5
# Thrown back into the dangerous underworld he'd tried to leave behind, Nathan Drake must decide what he's willing to sacrifice to save the ones he loves.
# 24939
# Grand Theft Auto V
# 2013 Video Game
# Action, Crime, Drama
# 9.5
# Three very different criminals team up for a series of heists in the corrupt city of Los Santos.
# 55516
# Mass Effect 2
# 2010 Video Game
# Action, Adventure, Sci-Fi
# 9.5
# After being revived from death and having to join a pro-human organization without a choice, Commander Shepard must assemble a team, battle a new threat, and make tough choices in order to save the galaxy from total annihilation once more.
# 19083
# Half-Life: Alyx
# 2020 Video Game
# Action, Adventure, Horror
# 9.5
# A VR game of an impossible fight against a vicious alien race known as the Combine, set between the events of Half-Life and Half-Life 2. Play as Alyx Vance, humanity's only chance for survival.
# 556
# Metal Gear Solid 3: Subsistence
# 2005 Video Game
# Action, Adventure, Drama
# 9.5
# Enhanced version of Metal Gear Solid 3: Snake Eater (2004) with many added features; such as the free range camera, new camouflage outfits, bonus levels and a theater mode.
# 2431
# Metal Gear Solid 3: Snake Eater
# 2004 Video Game
# Action, Adventure, Drama
# 9.5
# In 1964, a U.S. government operative codenamed "Snake" must infiltrate mountainous Soviet territory to rescue a scientist building a weapon of terrible power.
# 10096
# Star Wars: Knights of the Old Republic
# 2003 Video Game
# Action, Adventure, Fantasy
# 9.5
# A republic soldier, training to become a Jedi Knight, is given the task of halting the conquest of Darth Malak by discovering the location of a weapon known as the Star Forge.
# 8187
# Chrono Trigger
# 1995 Video Game
# Action, Adventure, Fantasy
# 9.5
# Crono, a young boy, is thrust to adventure by destiny to destroy an oncoming threat that will destroy the world in 1999.
# 2853
# Fainaru fantajî VII
# 1997 Video Game
# Action, Adventure, Fantasy
# 9.5
# A former soldier from an evil company joins a mercenary clan to fight the company he once served.
# 9450
# Uncharted: The Nathan Drake Collection
# 2015 Video Game
# Action, Adventure
# 9.4
# A remastered collection of Uncharted: Drake's Fortune (2007), Uncharted 2: Among Thieves (2009), and Uncharted 3: Drake's Deception (2011) for PlayStation 4.
# 4652
# Bloodborne: The Old Hunters
# 2015 Video Game
# Action, Adventure, Fantasy
# 9.4
# In this DLC for Bloodborne, the player-Hunter is transported to the sinister Hunter's Nightmare, a demented place where hunters who become drunk with blood are sent to.
# 1207
# Zeruda no densetsu: Buresu obu za wairudo
# 2017 Video Game
# Action, Adventure, Fantasy
# 9.4
# After a century of hibernation, Link reawakens to once again save a ruined Hyrule from a great evil.
# 5957
# The Elder Scrolls V: Skyrim
# 2011 Video Game
# Action, Adventure, Fantasy
# 9.4
# After escaping execution, the last living Dragonborn must grow in strength and power to defeat the dragons that have once again begun to plague the land of Skyrim.
# 27830
# Portal 2
# 2011 Video Game
# Action, Adventure, Comedy
# 9.4
# Many years after "Portal," Chell reawakens at Aperture Science and tries to stop GLADoS once again with the help of Wheatley, who has his own plans for the historical facility.
# 14586
# Halo 2: Anniversary
# 2014 Video Game
# Action, Adventure, Sci-Fi
# 9.4
# Add a Plot
# 11
# Batman: Arkham City
# 2011 Video Game
# Action, Adventure, Crime
# 9.4
# When part of Gotham is turned into a private reserve for criminals known as Arkham City, all hell is sure to break loose, and the Dark Knight is the only one who can stop it.
# 28703
# Devil May Cry 5: Special Edition
# 2020 Video Game
# Action, Adventure, Fantasy
# 9.4
# Add a Plot
# 11
# Red Dead Redemption
# 2010 Video Game
# banned
# |
#
# Action, Adventure, Crime
# 9.4
# A former outlaw is forced by the federal government to hunt down the members of his old gang.
# 25112
# Uncharted 2: Among Thieves
# 2009 Video Game
# Action, Adventure, Fantasy
# 9.4
# After being tracked down by Harry Flynn, Nathan Drake goes on a quest for Marco Polo's lost fleet. However when things take an unexpected turn for the worst, Drake must rely on those closest to him in order to find the Cintomani Stone.
# 22950
# Metal Gear Solid 4: Guns of the Patriots
# 2008 Video Game
# Action, Adventure, Drama
# 9.4
# When the nations of the world rely upon private military companies to fight their battles for them, renegade Liquid Ocelot emerges as the head of a potent coalition of mercenary powers. Solid Snake returns to save the world once again.
# 10345
# Grand Theft Auto: San Andreas
# 2004 Video Game
# Action, Crime
# 9.4
# A family tragedy prompts gangster Carl "CJ" Johnson to return home, only to find it overrun by crime and corruption, which he must regain control of the streets before it gets even worse.
# 37668
# Half-Life 2
# 2004 Video Game
# Action, Adventure, Horror
# 9.4
# Dr. Freeman is taken out of stasis by his "employer" to help rid the planet of invading aliens forces known as the Combine that entered through the portals he helped create.
# 15432
# Silent Hill 2
# 2001 Video Game
# Drama, Horror, Mystery
# 9.4
# After receiving a letter from his late wife, from Silent Hill, James Sunderland makes his way to the town in an attempt to find her.
# 6219
# Forgotten Realms: Baldur's Gate II - Shadows of Amn
# 2000 Video Game
# Action, Adventure, Fantasy
# 9.4
# Jon Irenicus, a sadistic secretive powerful mage bent on revenge, captures Gorion's ward and his/her party for a diabolical experiment.
# 2040
# Planescape: Torment
# 1999 Video Game
# Adventure, Drama, Fantasy
# 9.4
# In the city of Sigil, the only place from which all realities of the Planescape universe can be reached, an immortal amnesiac, the Nameless One, must uncover his past, the mystery of his immortality as well as who's trying to kill him.
# 1989
# Fallout 2: A Post-Nuclear Role-Playing Game
# 1998 Video Game
# Action, Adventure, Sci-Fi
# 9.4
# In a post-nuclear future, the descendant of an ancient exiled hero must leave his tribe in search of the Garden of Eden Creation Kit, the last chance of survival for his people.
# 3747
# Kirby's Extra Epic Yarn
# 2019 Video Game
# Adventure
# 9.3
# Add a Plot
# 71
# Ghost of Tsushima
# 2020 Video Game
# Action, Adventure, Drama
# 9.3
# Set in 1274 on the Tsushima Island, the last samurai, Jin Sakai, must master a new fighting style, the way of the Ghost, to defeat the Mongol forces and fight for the freedom and independence of Japan.
# 5962
# Kingdom Hearts HD 1.5 + 2.5 Remix
# 2017 Video Game
# Adventure, Family, Fantasy
# 9.3
# A re-release of Kingdom Hearts HD 1.5 Remix and Kingdom Hearts HD 2.5 Remix on the Playstation 4.
# 590
# Batman: Return to Arkham
# 2016 Video Game
# Action, Adventure, Crime
# 9.3
# Batman: Return to Arkham thrusts players back into the environments of Arkham Asylum and Arkham City with a remastered graphics engine and all DLC.
# 1415
# Persona 5
# 2016 Video Game
# Action, Adventure, Fantasy
# 9.3
# A group of high school students create a vigilante group to expose the crimes of corrupt adults but soon find themselves in the midst of a worldwide conspiracy and targeted by powerful individuals who would do anything to silence them.
# 2333
# Kingdom Hearts HD 2.5 Remix
# 2014 Video Game
# Action, Adventure, Family
# 9.3
# After the events of Kingdom Hearts HD 1.5 Remix (2013), a boy named Roxas wakes up in Twilight Town trying to make it through his last days of summer vacation when he finds out that his dreams are actually Sora's memories and he must return them to him.
# 791
# Super Mario All-Stars + Super Mario World
# 1994 Video Game
# Action, Adventure, Family
# 9.3
# A compilation game that includes both Super Mario All-Stars and Super Mario World on one game.
# 329
# P.T.
# 2014 Video Game
# Horror, Mystery
# 9.3
# The player must navigate a series of continuously looping hallways, solving cryptic puzzles, all while being hunted by a hostile apparition named Lisa.
# 1516
# Persona 4 Golden
# 2012 Video Game
# Action, Adventure, Fantasy
# 9.3
# A group of high school students discover a hidden TV world called 'The Midnight Channel', an alternate reality infested with shadows that is being used to commit murder. After awakening to their Personas, the group decides to investigate.
# 901
# It Takes Two
# 2021 Video Game
# Adventure, Comedy, Drama
# 9.3
# Embark on the craziest journey of your life in It Takes Two, a genre-bending platform adventure created purely for co-op. Invite a friend to join for free with Friend's Pass and work ...                See full summary »
# 886
# Omori
# 2020 Video Game
# Adventure, Drama, Fantasy
# 9.3
# A young man traverses various mundane, quirky, humorous, mysterious and horrific lands with his friends in search of a missing person while confronting his traumatic past and fears.
# 119
# Persona 4
# 2008 Video Game
# Action, Adventure, Fantasy
# 9.3
# A high school student forms a group that explores a hidden world accessible through TV sets to find a connection between the "realm of shadows" and the mysterious murders in their town.
# 958
# Kingdom Hearts II: Final Mix+
# 2007 Video Game
# Adventure, Fantasy
# 9.3
# Sora and friends must set out on another adventure to find his long lost friends and stop Organization XIII.
# 1205
# Wanda to kyozô
# 2005 Video Game
# Action, Adventure, Drama
# 9.3
# A young man brings a deceased woman to a forbidden land inhabited by colossal beings said to house the power to revive the dead.
# 3830

# %%
    print(clean_num(get_data_votes(i, "p","sort-num_votes-visible")))
# Out:
# 3830

# %%
Vgame_list = []

for i in (soup.find_all('div','lister-item mode-advanced')):
    title = get_data_a_tag(i, "h3","lister-item-header")
    year = get_data(i, "span", "lister-item-year text-muted unbold")
    Gtype = get_data(i, "p", "text-muted").strip()
    rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
    descr = get_data_descr(i, "p","text-muted")
    votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
    headers = ['title', 'year', 'game_type', 'rate', 'descr','votes']
    Vgame_dict = dict(zip(headers, [ title,
                                    year,
                                    Gtype,
                                    rate,
                                    descr, 
                                    votes]))
    Vgame_list.append(Vgame_dict)

# %%
    Vgame_list
# Out:
# [{'title': 'Wiedzmin 3: Dziki Gon Krew i wino',
#   'year': '2016 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.8',
#   'descr': "Geralt is in the southern province of Toussaint where a monstrous serial killer is targeting knights with a dark past. Geralt and his old vampire friend investigate the killer's motives.",
#   'votes': '6810'},
#  {'title': 'Red Dead Redemption II',
#   'year': '2018 Video Game',
#   'game_type': 'Action, Adventure, Crime',
#   'rate': '9.7',
#   'descr': 'Amidst the decline of the Wild West at the turn of the 20th century, outlaw Arthur Morgan and his gang struggle to cope with the loss of their way of life.',
#   'votes': '28686'},
#  {'title': 'Wiedzmin 3: Dziki Gon',
#   'year': '2015 Video Game',
#   'game_type': 'banned\n|\n\nAction, Adventure, Drama',
#   'rate': '9.7',
#   'descr': 'A monster hunter for hire embarks on an epic journey to find his former apprentice before The Wild Hunt can capture her and bring about the destruction of the world.',
#   'votes': '23029'},
#  {'title': 'The Last of Us',
#   'year': '2013 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.7',
#   'descr': 'In a hostile, post-pandemic world, Joel and Ellie, brought together by desperate circumstances, must rely on each other to survive a brutal journey across what remains of the United States.',
#   'votes': '55702'},
#  {'title': 'Mass Effect: Legendary Edition',
#   'year': '2021 Video Game',
#   'game_type': 'Sci-Fi',
#   'rate': '9.7',
#   'descr': 'A compilation of the first three Mass Effect games.',
#   'votes': '706'},
#  {'title': 'God of War',
#   'year': '2018 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.6',
#   'descr': 'After wiping out the gods of Mount Olympus, Kratos moves on to the frigid lands of Scandinavia, where he and his son must embark on an odyssey across a dangerous world of gods and monsters.',
#   'votes': '21310'},
#  {'title': 'Perusona 5: Za roiyaru',
#   'year': '2019 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.6',
#   'descr': 'A group of high school students create a vigilante group to expose the crimes of corrupt adults but soon find themselves in the midst of a worldwide conspiracy and targeted by powerful individuals who would do anything to silence them.',
#   'votes': '798'},
#  {'title': 'Zeruda no densetsu: Toki no okarina',
#   'year': '1998 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.6',
#   'descr': 'A young Kokiri boy discovers that his destiny is to free the Seven Sages and save the land of Hyrule from the treacherous sorcerer Ganondorf.',
#   'votes': '8998'},
#  {'title': 'Metal Gear Solid',
#   'year': '1998 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.6',
#   'descr': "A crack government anti-terrorist squad takes over an obscure Alaskan nuclear disposal facility. Solid Snake is up for the task to infiltrate the facility, rescue the two hostages and thwart the terrorists' plans.",
#   'votes': '11329'},
#  {'title': 'Wiedzmin 3: Dziki Gon - Serca z kamienia',
#   'year': '2015 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.5',
#   'descr': 'Geralt is forced by a seemingly harmless merchant with sinister powers to complete three difficult tasks for a bored immortal, once a troubled nobleman who made a deal with the devil.',
#   'votes': '5679'},
#  {'title': "Uncharted 4: A Thief's End",
#   'year': '2016 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.5',
#   'descr': "Thrown back into the dangerous underworld he'd tried to leave behind, Nathan Drake must decide what he's willing to sacrifice to save the ones he loves.",
#   'votes': '24939'},
#  {'title': 'Grand Theft Auto V',
#   'year': '2013 Video Game',
#   'game_type': 'Action, Crime, Drama',
#   'rate': '9.5',
#   'descr': 'Three very different criminals team up for a series of heists in the corrupt city of Los Santos.',
#   'votes': '55516'},
#  {'title': 'Mass Effect 2',
#   'year': '2010 Video Game',
#   'game_type': 'Action, Adventure, Sci-Fi',
#   'rate': '9.5',
#   'descr': 'After being revived from death and having to join a pro-human organization without a choice, Commander Shepard must assemble a team, battle a new threat, and make tough choices in order to save the galaxy from total annihilation once more.',
#   'votes': '19083'},
#  {'title': 'Half-Life: Alyx',
#   'year': '2020 Video Game',
#   'game_type': 'Action, Adventure, Horror',
#   'rate': '9.5',
#   'descr': "A VR game of an impossible fight against a vicious alien race known as the Combine, set between the events of Half-Life and Half-Life 2. Play as Alyx Vance, humanity's only chance for survival.",
#   'votes': '556'},
#  {'title': 'Metal Gear Solid 3: Subsistence',
#   'year': '2005 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.5',
#   'descr': 'Enhanced version of Metal Gear Solid 3: Snake Eater (2004) with many added features; such as the free range camera, new camouflage outfits, bonus levels and a theater mode.',
#   'votes': '2431'},
#  {'title': 'Metal Gear Solid 3: Snake Eater',
#   'year': '2004 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.5',
#   'descr': 'In 1964, a U.S. government operative codenamed "Snake" must infiltrate mountainous Soviet territory to rescue a scientist building a weapon of terrible power.',
#   'votes': '10096'},
#  {'title': 'Star Wars: Knights of the Old Republic',
#   'year': '2003 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.5',
#   'descr': 'A republic soldier, training to become a Jedi Knight, is given the task of halting the conquest of Darth Malak by discovering the location of a weapon known as the Star Forge.',
#   'votes': '8187'},
#  {'title': 'Chrono Trigger',
#   'year': '1995 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.5',
#   'descr': 'Crono, a young boy, is thrust to adventure by destiny to destroy an oncoming threat that will destroy the world in 1999.',
#   'votes': '2853'},
#  {'title': 'Fainaru fantajî VII',
#   'year': '1997 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.5',
#   'descr': 'A former soldier from an evil company joins a mercenary clan to fight the company he once served.',
#   'votes': '9450'},
#  {'title': 'Uncharted: The Nathan Drake Collection',
#   'year': '2015 Video Game',
#   'game_type': 'Action, Adventure',
#   'rate': '9.4',
#   'descr': "A remastered collection of Uncharted: Drake's Fortune (2007), Uncharted 2: Among Thieves (2009), and Uncharted 3: Drake's Deception (2011) for PlayStation 4.",
#   'votes': '4652'},
#  {'title': 'Bloodborne: The Old Hunters',
#   'year': '2015 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.4',
#   'descr': "In this DLC for Bloodborne, the player-Hunter is transported to the sinister Hunter's Nightmare, a demented place where hunters who become drunk with blood are sent to.",
#   'votes': '1207'},
#  {'title': 'Zeruda no densetsu: Buresu obu za wairudo',
#   'year': '2017 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.4',
#   'descr': 'After a century of hibernation, Link reawakens to once again save a ruined Hyrule from a great evil.',
#   'votes': '5957'},
#  {'title': 'The Elder Scrolls V: Skyrim',
#   'year': '2011 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.4',
#   'descr': 'After escaping execution, the last living Dragonborn must grow in strength and power to defeat the dragons that have once again begun to plague the land of Skyrim.',
#   'votes': '27830'},
#  {'title': 'Portal 2',
#   'year': '2011 Video Game',
#   'game_type': 'Action, Adventure, Comedy',
#   'rate': '9.4',
#   'descr': 'Many years after "Portal," Chell reawakens at Aperture Science and tries to stop GLADoS once again with the help of Wheatley, who has his own plans for the historical facility.',
#   'votes': '14586'},
#  {'title': 'Halo 2: Anniversary',
#   'year': '2014 Video Game',
#   'game_type': 'Action, Adventure, Sci-Fi',
#   'rate': '9.4',
#   'descr': 'Add a Plot',
#   'votes': '11'},
#  {'title': 'Batman: Arkham City',
#   'year': '2011 Video Game',
#   'game_type': 'Action, Adventure, Crime',
#   'rate': '9.4',
#   'descr': 'When part of Gotham is turned into a private reserve for criminals known as Arkham City, all hell is sure to break loose, and the Dark Knight is the only one who can stop it.',
#   'votes': '28703'},
#  {'title': 'Devil May Cry 5: Special Edition',
#   'year': '2020 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.4',
#   'descr': 'Add a Plot',
#   'votes': '11'},
#  {'title': 'Red Dead Redemption',
#   'year': '2010 Video Game',
#   'game_type': 'banned\n|\n\nAction, Adventure, Crime',
#   'rate': '9.4',
#   'descr': 'A former outlaw is forced by the federal government to hunt down the members of his old gang.',
#   'votes': '25112'},
#  {'title': 'Uncharted 2: Among Thieves',
#   'year': '2009 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.4',
#   'descr': "After being tracked down by Harry Flynn, Nathan Drake goes on a quest for Marco Polo's lost fleet. However when things take an unexpected turn for the worst, Drake must rely on those closest to him in order to find the Cintomani Stone.",
#   'votes': '22950'},
#  {'title': 'Metal Gear Solid 4: Guns of the Patriots',
#   'year': '2008 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.4',
#   'descr': 'When the nations of the world rely upon private military companies to fight their battles for them, renegade Liquid Ocelot emerges as the head of a potent coalition of mercenary powers. Solid Snake returns to save the world once again.',
#   'votes': '10345'},
#  {'title': 'Grand Theft Auto: San Andreas',
#   'year': '2004 Video Game',
#   'game_type': 'Action, Crime',
#   'rate': '9.4',
#   'descr': 'A family tragedy prompts gangster Carl "CJ" Johnson to return home, only to find it overrun by crime and corruption, which he must regain control of the streets before it gets even worse.',
#   'votes': '37668'},
#  {'title': 'Half-Life 2',
#   'year': '2004 Video Game',
#   'game_type': 'Action, Adventure, Horror',
#   'rate': '9.4',
#   'descr': 'Dr. Freeman is taken out of stasis by his "employer" to help rid the planet of invading aliens forces known as the Combine that entered through the portals he helped create.',
#   'votes': '15432'},
#  {'title': 'Silent Hill 2',
#   'year': '2001 Video Game',
#   'game_type': 'Drama, Horror, Mystery',
#   'rate': '9.4',
#   'descr': 'After receiving a letter from his late wife, from Silent Hill, James Sunderland makes his way to the town in an attempt to find her.',
#   'votes': '6219'},
#  {'title': "Forgotten Realms: Baldur's Gate II - Shadows of Amn",
#   'year': '2000 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.4',
#   'descr': "Jon Irenicus, a sadistic secretive powerful mage bent on revenge, captures Gorion's ward and his/her party for a diabolical experiment.",
#   'votes': '2040'},
#  {'title': 'Planescape: Torment',
#   'year': '1999 Video Game',
#   'game_type': 'Adventure, Drama, Fantasy',
#   'rate': '9.4',
#   'descr': "In the city of Sigil, the only place from which all realities of the Planescape universe can be reached, an immortal amnesiac, the Nameless One, must uncover his past, the mystery of his immortality as well as who's trying to kill him.",
#   'votes': '1989'},
#  {'title': 'Fallout 2: A Post-Nuclear Role-Playing Game',
#   'year': '1998 Video Game',
#   'game_type': 'Action, Adventure, Sci-Fi',
#   'rate': '9.4',
#   'descr': 'In a post-nuclear future, the descendant of an ancient exiled hero must leave his tribe in search of the Garden of Eden Creation Kit, the last chance of survival for his people.',
#   'votes': '3747'},
#  {'title': "Kirby's Extra Epic Yarn",
#   'year': '2019 Video Game',
#   'game_type': 'Adventure',
#   'rate': '9.3',
#   'descr': 'Add a Plot',
#   'votes': '71'},
#  {'title': 'Ghost of Tsushima',
#   'year': '2020 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.3',
#   'descr': 'Set in 1274 on the Tsushima Island, the last samurai, Jin Sakai, must master a new fighting style, the way of the Ghost, to defeat the Mongol forces and fight for the freedom and independence of Japan.',
#   'votes': '5962'},
#  {'title': 'Kingdom Hearts HD 1.5 + 2.5 Remix',
#   'year': '2017 Video Game',
#   'game_type': 'Adventure, Family, Fantasy',
#   'rate': '9.3',
#   'descr': 'A re-release of Kingdom Hearts HD 1.5 Remix and Kingdom Hearts HD 2.5 Remix on the Playstation 4.',
#   'votes': '590'},
#  {'title': 'Batman: Return to Arkham',
#   'year': '2016 Video Game',
#   'game_type': 'Action, Adventure, Crime',
#   'rate': '9.3',
#   'descr': 'Batman: Return to Arkham thrusts players back into the environments of Arkham Asylum and Arkham City with a remastered graphics engine and all DLC.',
#   'votes': '1415'},
#  {'title': 'Persona 5',
#   'year': '2016 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.3',
#   'descr': 'A group of high school students create a vigilante group to expose the crimes of corrupt adults but soon find themselves in the midst of a worldwide conspiracy and targeted by powerful individuals who would do anything to silence them.',
#   'votes': '2333'},
#  {'title': 'Kingdom Hearts HD 2.5 Remix',
#   'year': '2014 Video Game',
#   'game_type': 'Action, Adventure, Family',
#   'rate': '9.3',
#   'descr': "After the events of Kingdom Hearts HD 1.5 Remix (2013), a boy named Roxas wakes up in Twilight Town trying to make it through his last days of summer vacation when he finds out that his dreams are actually Sora's memories and he must return them to him.",
#   'votes': '791'},
#  {'title': 'Super Mario All-Stars + Super Mario World',
#   'year': '1994 Video Game',
#   'game_type': 'Action, Adventure, Family',
#   'rate': '9.3',
#   'descr': 'A compilation game that includes both Super Mario All-Stars and Super Mario World on one game.',
#   'votes': '329'},
#  {'title': 'P.T.',
#   'year': '2014 Video Game',
#   'game_type': 'Horror, Mystery',
#   'rate': '9.3',
#   'descr': 'The player must navigate a series of continuously looping hallways, solving cryptic puzzles, all while being hunted by a hostile apparition named Lisa.',
#   'votes': '1516'},
#  {'title': 'Persona 4 Golden',
#   'year': '2012 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.3',
#   'descr': "A group of high school students discover a hidden TV world called 'The Midnight Channel', an alternate reality infested with shadows that is being used to commit murder. After awakening to their Personas, the group decides to investigate.",
#   'votes': '901'},
#  {'title': 'It Takes Two',
#   'year': '2021 Video Game',
#   'game_type': 'Adventure, Comedy, Drama',
#   'rate': '9.3',
#   'descr': "Embark on the craziest journey of your life in It Takes Two, a genre-bending platform adventure created purely for co-op. Invite a friend to join for free with Friend's Pass and work ...                See full summary\xa0»",
#   'votes': '886'},
#  {'title': 'Omori',
#   'year': '2020 Video Game',
#   'game_type': 'Adventure, Drama, Fantasy',
#   'rate': '9.3',
#   'descr': 'A young man traverses various mundane, quirky, humorous, mysterious and horrific lands with his friends in search of a missing person while confronting his traumatic past and fears.',
#   'votes': '119'},
#  {'title': 'Persona 4',
#   'year': '2008 Video Game',
#   'game_type': 'Action, Adventure, Fantasy',
#   'rate': '9.3',
#   'descr': 'A high school student forms a group that explores a hidden world accessible through TV sets to find a connection between the "realm of shadows" and the mysterious murders in their town.',
#   'votes': '958'},
#  {'title': 'Kingdom Hearts II: Final Mix+',
#   'year': '2007 Video Game',
#   'game_type': 'Adventure, Fantasy',
#   'rate': '9.3',
#   'descr': 'Sora and friends must set out on another adventure to find his long lost friends and stop Organization XIII.',
#   'votes': '1205'},
#  {'title': 'Wanda to kyozô',
#   'year': '2005 Video Game',
#   'game_type': 'Action, Adventure, Drama',
#   'rate': '9.3',
#   'descr': 'A young man brings a deceased woman to a forbidden land inhabited by colossal beings said to house the power to revive the dead.',
#   'votes': '3830'}]

# %%
df = pd.DataFrame(Vgame_list)
df
# Out:
#                                                 title             year  \
# 0                   Wiedzmin 3: Dziki Gon Krew i wino  2016 Video Game
# 1                              Red Dead Redemption II  2018 Video Game
# 2                               Wiedzmin 3: Dziki Gon  2015 Video Game
# 3                                      The Last of Us  2013 Video Game
# 4                      Mass Effect: Legendary Edition  2021 Video Game
# 5                                          God of War  2018 Video Game
# 6                              Perusona 5: Za roiyaru  2019 Video Game
# 7                 Zeruda no densetsu: Toki no okarina  1998 Video Game
# 8                                    Metal Gear Solid  1998 Video Game
# 9            Wiedzmin 3: Dziki Gon - Serca z kamienia  2015 Video Game
# 10                         Uncharted 4: A Thief's End  2016 Video Game
# 11                                 Grand Theft Auto V  2013 Video Game
# 12                                      Mass Effect 2  2010 Video Game
# 13                                    Half-Life: Alyx  2020 Video Game
# 14                    Metal Gear Solid 3: Subsistence  2005 Video Game
# 15                    Metal Gear Solid 3: Snake Eater  2004 Video Game
# 16             Star Wars: Knights of the Old Republic  2003 Video Game
# 17                                     Chrono Trigger  1995 Video Game
# 18                                Fainaru fantajî VII  1997 Video Game
# 19             Uncharted: The Nathan Drake Collection  2015 Video Game
# 20                        Bloodborne: The Old Hunters  2015 Video Game
# 21          Zeruda no densetsu: Buresu obu za wairudo  2017 Video Game
# 22                        The Elder Scrolls V: Skyrim  2011 Video Game
# 23                                           Portal 2  2011 Video Game
# 24                                Halo 2: Anniversary  2014 Video Game
# 25                                Batman: Arkham City  2011 Video Game
# 26                   Devil May Cry 5: Special Edition  2020 Video Game
# 27                                Red Dead Redemption  2010 Video Game
# 28                         Uncharted 2: Among Thieves  2009 Video Game
# 29           Metal Gear Solid 4: Guns of the Patriots  2008 Video Game
# 30                      Grand Theft Auto: San Andreas  2004 Video Game
# 31                                        Half-Life 2  2004 Video Game
# 32                                      Silent Hill 2  2001 Video Game
# 33  Forgotten Realms: Baldur's Gate II - Shadows o...  2000 Video Game
# 34                                Planescape: Torment  1999 Video Game
# 35        Fallout 2: A Post-Nuclear Role-Playing Game  1998 Video Game
# 36                            Kirby's Extra Epic Yarn  2019 Video Game
# 37                                  Ghost of Tsushima  2020 Video Game
# 38                  Kingdom Hearts HD 1.5 + 2.5 Remix  2017 Video Game
# 39                           Batman: Return to Arkham  2016 Video Game
# 40                                          Persona 5  2016 Video Game
# 41                        Kingdom Hearts HD 2.5 Remix  2014 Video Game
# 42          Super Mario All-Stars + Super Mario World  1994 Video Game
# 43                                               P.T.  2014 Video Game
# 44                                   Persona 4 Golden  2012 Video Game
# 45                                       It Takes Two  2021 Video Game
# 46                                              Omori  2020 Video Game
# 47                                          Persona 4  2008 Video Game
# 48                      Kingdom Hearts II: Final Mix+  2007 Video Game
# 49                                     Wanda to kyozô  2005 Video Game
#
#                                 game_type rate  \
# 0                Action, Adventure, Drama  9.8
# 1                Action, Adventure, Crime  9.7
# 2   banned\n|\n\nAction, Adventure, Drama  9.7
# 3                Action, Adventure, Drama  9.7
# 4                                  Sci-Fi  9.7
# 5                Action, Adventure, Drama  9.6
# 6              Action, Adventure, Fantasy  9.6
# 7              Action, Adventure, Fantasy  9.6
# 8                Action, Adventure, Drama  9.6
# 9                Action, Adventure, Drama  9.5
# 10               Action, Adventure, Drama  9.5
# 11                   Action, Crime, Drama  9.5
# 12              Action, Adventure, Sci-Fi  9.5
# 13              Action, Adventure, Horror  9.5
# 14               Action, Adventure, Drama  9.5
# 15               Action, Adventure, Drama  9.5
# 16             Action, Adventure, Fantasy  9.5
# 17             Action, Adventure, Fantasy  9.5
# 18             Action, Adventure, Fantasy  9.5
# 19                      Action, Adventure  9.4
# 20             Action, Adventure, Fantasy  9.4
# 21             Action, Adventure, Fantasy  9.4
# 22             Action, Adventure, Fantasy  9.4
# 23              Action, Adventure, Comedy  9.4
# 24              Action, Adventure, Sci-Fi  9.4
# 25               Action, Adventure, Crime  9.4
# 26             Action, Adventure, Fantasy  9.4
# 27  banned\n|\n\nAction, Adventure, Crime  9.4
# 28             Action, Adventure, Fantasy  9.4
# 29               Action, Adventure, Drama  9.4
# 30                          Action, Crime  9.4
# 31              Action, Adventure, Horror  9.4
# 32                 Drama, Horror, Mystery  9.4
# 33             Action, Adventure, Fantasy  9.4
# 34              Adventure, Drama, Fantasy  9.4
# 35              Action, Adventure, Sci-Fi  9.4
# 36                              Adventure  9.3
# 37               Action, Adventure, Drama  9.3
# 38             Adventure, Family, Fantasy  9.3
# 39               Action, Adventure, Crime  9.3
# 40             Action, Adventure, Fantasy  9.3
# 41              Action, Adventure, Family  9.3
# 42              Action, Adventure, Family  9.3
# 43                        Horror, Mystery  9.3
# 44             Action, Adventure, Fantasy  9.3
# 45               Adventure, Comedy, Drama  9.3
# 46              Adventure, Drama, Fantasy  9.3
# 47             Action, Adventure, Fantasy  9.3
# 48                     Adventure, Fantasy  9.3
# 49               Action, Adventure, Drama  9.3
#
#                                                 descr  votes
# 0   Geralt is in the southern province of Toussain...   6810
# 1   Amidst the decline of the Wild West at the tur...  28686
# 2   A monster hunter for hire embarks on an epic j...  23029
# 3   In a hostile, post-pandemic world, Joel and El...  55702
# 4   A compilation of the first three Mass Effect g...    706
# 5   After wiping out the gods of Mount Olympus, Kr...  21310
# 6   A group of high school students create a vigil...    798
# 7   A young Kokiri boy discovers that his destiny ...   8998
# 8   A crack government anti-terrorist squad takes ...  11329
# 9   Geralt is forced by a seemingly harmless merch...   5679
# 10  Thrown back into the dangerous underworld he'd...  24939
# 11  Three very different criminals team up for a s...  55516
# 12  After being revived from death and having to j...  19083
# 13  A VR game of an impossible fight against a vic...    556
# 14  Enhanced version of Metal Gear Solid 3: Snake ...   2431
# 15  In 1964, a U.S. government operative codenamed...  10096
# 16  A republic soldier, training to become a Jedi ...   8187
# 17  Crono, a young boy, is thrust to adventure by ...   2853
# 18  A former soldier from an evil company joins a ...   9450
# 19  A remastered collection of Uncharted: Drake's ...   4652
# 20  In this DLC for Bloodborne, the player-Hunter ...   1207
# 21  After a century of hibernation, Link reawakens...   5957
# 22  After escaping execution, the last living Drag...  27830
# 23  Many years after "Portal," Chell reawakens at ...  14586
# 24                                         Add a Plot     11
# 25  When part of Gotham is turned into a private r...  28703
# 26                                         Add a Plot     11
# 27  A former outlaw is forced by the federal gover...  25112
# 28  After being tracked down by Harry Flynn, Natha...  22950
# 29  When the nations of the world rely upon privat...  10345
# 30  A family tragedy prompts gangster Carl "CJ" Jo...  37668
# 31  Dr. Freeman is taken out of stasis by his "emp...  15432
# 32  After receiving a letter from his late wife, f...   6219
# 33  Jon Irenicus, a sadistic secretive powerful ma...   2040
# 34  In the city of Sigil, the only place from whic...   1989
# 35  In a post-nuclear future, the descendant of an...   3747
# 36                                         Add a Plot     71
# 37  Set in 1274 on the Tsushima Island, the last s...   5962
# 38  A re-release of Kingdom Hearts HD 1.5 Remix an...    590
# 39  Batman: Return to Arkham thrusts players back ...   1415
# 40  A group of high school students create a vigil...   2333
# 41  After the events of Kingdom Hearts HD 1.5 Remi...    791
# 42  A compilation game that includes both Super Ma...    329
# 43  The player must navigate a series of continuou...   1516
# 44  A group of high school students discover a hid...    901
# 45  Embark on the craziest journey of your life in...    886
# 46  A young man traverses various mundane, quirky,...    119
# 47  A high school student forms a group that explo...    958
# 48  Sora and friends must set out on another adven...   1205
# 49  A young man brings a deceased woman to a forbi...   3830

# %%
df.to_csv('video_game.csv')
