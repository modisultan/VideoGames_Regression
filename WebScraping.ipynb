# %% [markdown]
# # Web Scrape Video Games
# > <a href=#imports>Import Libraries</a>
#
# > <a href=#webscrabing>Web Scraping</a>
#
# > <a href=#merge>Merging Data</a>
#
# > <a href=#EDA>Explratory Data Analysis (EDA)</a>

# %% [markdown]
# # <a name=imports> Import Libraries</a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <a name=webscrabing>Web Scraping</a>

# %%
url = "https://www.imdb.com/search/title/?title_type=video_game"

response = requests.get(url)
response.status_code
page = response.text
soup = BeautifulSoup(page, "lxml")

# %%
def clean_num(s):
    """cleans text scraped from website
    
    Parameters:
    s (String): raw text

    Returns:
    String: cleaned digit text

    """ 

    if s is None:
        return s
    return "".join(re.findall('\d*\.?\d+',s))

def get_data(block, tag, class_text):
    """fetch data from tag and its associated class
    
    Parameters:
    block (int): Book item 
    tag (String): tag for element we want to fetch
    class_text (String): class for element we want to fetch

    Returns:
    String: data text fetched

    """ 
    try:
        return block.find(tag, class_ = class_text).text.replace('(','').replace(')','')
    except AttributeError:
        return ""
    return

def get_data_a_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).a.text
    except AttributeError:
        return ""
    return
def get_data_strong_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).strong.text
    except AttributeError:
        return ""
    return
def get_data_descr(i, tag, class_text):    
    try:
        return i.find_all(tag, class_ = class_text)[1].text.strip()
    except AttributeError:
        return ""
    return


def get_data_votes(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).text.split()[1].replace(',','')
    except AttributeError:
        return ""
    return

# %%
    
Vgame_list = []

for i in (soup.find_all('div','lister-item mode-advanced')):
    Name = get_data_a_tag(i, "h3","lister-item-header")
    year = get_data(i, "span", "lister-item-year text-muted unbold").split()[0]
    Gtype = get_data(i, "p", "text-muted").strip()
    rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
    votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
    headers = ['Name', 'year', 'game_type', 'rate','votes']
    Vgame_dict = dict(zip(headers, [ Name,
                                    year,
                                    Gtype,
                                    rate,
                                    votes]))
    Vgame_list.append(Vgame_dict)

# %%
vedioGame = pd.DataFrame(Vgame_list) #transpose
vedioGame
# Out:
#                                  Name   year  \
# 0    Marvel's Guardians of the Galaxy   2021
# 1              Red Dead Redemption II   2018
# 2       Grand Theft Auto: San Andreas   2004
# 3                  Grand Theft Auto V   2013
# 4                      Cyberpunk 2077   2020
# 5              Call of Duty: Vanguard   2021
# 6             The Last of Us: Part II   2020
# 7                       Halo Infinite   2021
# 8                           Far Cry 6   2021
# 9                     Death Stranding   2019
# 10                         Spider-Man   2018
# 11                     The Last of Us   2013
# 12          Spider-Man: Miles Morales   2020
# 13              Detroit: Become Human   2018
# 14                         Until Dawn   2015
# 15        Grand Theft Auto: Vice City   2002
# 16          Assassin's Creed Valhalla   2020
# 17       Star Wars Jedi: Fallen Order   2019
# 18                  Marvel's Avengers   2020
# 19                         God of War   2018
# 20              Wiedzmin 3: Dziki Gon   2015
# 21              Resident Evil Village   2021
# 22                  Ghost of Tsushima   2020
# 23  The Dark Pictures: House of Ashes   2021
# 24        The Elder Scrolls V: Skyrim   2011
# 25                   Battlefield 2042   2021
# 26                  League of Legends   2009
# 27                  Horizon Zero Dawn   2017
# 28              Batman: Arkham Knight   2015
# 29                       It Takes Two   2021
# 30                       Ghostbusters   2009
# 31         Uncharted 4: A Thief's End   2016
# 32                Grand Theft Auto IV   2008
# 33                          Far Cry 3   2012
# 34               Grand Theft Auto III   2001
# 35     Mass Effect: Legendary Edition   2021
# 36           Final Fantasy VII Remake   2020
# 37                        Mass Effect   2007
# 38                        Squadron 42  Video
# 39                Red Dead Redemption   2010
# 40                          Fallout 4   2015
# 41       Call of Duty: Modern Warfare   2019
# 42               God of War: Ragnarök   2022
# 43                          Far Cry 5   2018
# 44                      Mass Effect 2   2010
# 45                   Mortal Kombat 11   2019
# 46                          Days Gone   2019
# 47                  Halo 5: Guardians   2015
# 48                     Genshin Impact   2020
# 49                Batman: Arkham City   2011
#
#                                             game_type rate  votes
# 0                           Action, Adventure, Comedy  9.1    949
# 1                            Action, Adventure, Crime  9.7  28888
# 2                                       Action, Crime  9.4  37749
# 3                                Action, Crime, Drama  9.5  55657
# 4                                Action, Crime, Drama  7.9   5948
# 5                          Action, Adventure, History  6.3    505
# 6               banned\n|\n\nAction, Adventure, Drama  8.3  26194
# 7   Action, Adventure, Sci-Fi            \n|\nComp...
# 8                                   Action, Adventure  8.1    818
# 9                            Action, Adventure, Drama  8.9   6992
# 10                         Action, Adventure, Fantasy  9.2  16923
# 11                           Action, Adventure, Drama  9.7  55858
# 12                           Action, Adventure, Crime  8.6   3515
# 13                           Action, Adventure, Drama  9.2  14279
# 14                          Horror, Mystery, Thriller  8.8  12992
# 15                               Action, Crime, Drama  9.2  25159
# 16                         Action, Adventure, Fantasy  8.2   2739
# 17                           Action, Adventure, Drama  8.6   8514
# 18                         Action, Adventure, Fantasy  6.4   1832
# 19                           Action, Adventure, Drama  9.6  21417
# 20              banned\n|\n\nAction, Adventure, Drama  9.7  23123
# 21                         Action, Adventure, Fantasy  8.8   3267
# 22                           Action, Adventure, Drama  9.3   6036
# 23                          Action, Adventure, Horror  7.9    497
# 24                         Action, Adventure, Fantasy  9.4  27895
# 25                          Action, Adventure, Sci-Fi  3.5    210
# 26                         Action, Adventure, Fantasy  7.3   2433
# 27                         Action, Adventure, Mystery  9.1  11684
# 28                           Action, Adventure, Crime  9.0  16704
# 29                           Adventure, Comedy, Drama  9.3    944
# 30                          Action, Adventure, Comedy  8.5   2875
# 31                           Action, Adventure, Drama  9.5  25034
# 32                               Action, Crime, Drama  8.9  33343
# 33                                  Action, Adventure  8.9  17568
# 34                               Action, Crime, Drama  8.7  15050
# 35                                             Sci-Fi  9.7    756
# 36                         Action, Adventure, Fantasy  9.1   2986
# 37                          Action, Adventure, Sci-Fi  9.2  17374
# 38           Action, Sci-Fi            \n|\nAnnounced
# 39              banned\n|\n\nAction, Adventure, Crime  9.4  25169
# 40                           Action, Adventure, Drama  8.6  11856
# 41                        Action, Adventure, Thriller  8.4   4318
# 42  Action, Adventure, Drama            \n|\nPost-...
# 43                         Action, Adventure, Western  8.0   5914
# 44                          Action, Adventure, Sci-Fi  9.5  19116
# 45                         Action, Adventure, Fantasy  7.9   2951
# 46                          Action, Adventure, Horror  8.4   4916
# 47                         Action, Adventure, Mystery  7.2   2725
# 48                         Action, Adventure, Fantasy  7.8    712
# 49                           Action, Adventure, Crime  9.4  28776

# %%
def get_movie_dict(link):

    #Create full url to scrape
    url =link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
  
    
    for i in (soup.find_all('div','lister-item mode-advanced')):        
        Name = get_data_a_tag(i, "h3","lister-item-header")
        year = get_data(i, "span", "lister-item-year text-muted unbold").split()[0]
        Gtype = get_data(i, "p", "text-muted").strip()
        rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
        votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
        headers = ['Name', 'year', 'game_type', 'rate','votes']
        #Create game vedio dictionary and return
        movie_dict = dict(zip(headers, [ Name,
                                    year,
                                    Gtype,
                                    rate,
                                    votes]))
        Vgame_list.append(movie_dict) 

    return movie_dict

# %%
get_movie_dict("https://www.imdb.com/search/title/?title_type=video_game&start=51&ref_=adv_nxt")
# Out:
# {'Name': 'Call of Duty: WWII',
#  'year': '2017',
#  'game_type': 'Action, Adventure, Drama',
#  'rate': '7.7',
#  'votes': '5600'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=101&ref_=adv_nxt')
# Out:
# {'Name': 'NieR: Automata',
#  'year': '2017',
#  'game_type': 'Action, Adventure, Drama',
#  'rate': '8.9',
#  'votes': '2451'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=151&ref_=adv_nxt')
# Out:
# {'Name': 'Metro Exodus',
#  'year': '2019',
#  'game_type': 'Action, Adventure, Horror',
#  'rate': '8.2',
#  'votes': '1966'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=201&ref_=adv_nxt')
# Out:
# {'Name': 'Half-Life: Alyx',
#  'year': '2020',
#  'game_type': 'Action, Adventure, Horror',
#  'rate': '9.5',
#  'votes': '561'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=251&ref_=adv_nxt')
# Out:
# {'Name': 'Titanfall 2',
#  'year': '2016',
#  'game_type': 'Action, Adventure, Sci-Fi',
#  'rate': '8.5',
#  'votes': '3254'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=301&ref_=adv_nxt')
# Out:
# {'Name': 'Command & Conquer: Red Alert 2',
#  'year': '2000',
#  'game_type': 'Action, Sci-Fi, War',
#  'rate': '8.6',
#  'votes': '2902'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=351&ref_=adv_nxt')
# Out:
# {'Name': 'Battlefield: Hardline',
#  'year': '2015',
#  'game_type': 'Action, Crime',
#  'rate': '6.5',
#  'votes': '2363'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=401&ref_=adv_nxt')
# Out:
# {'Name': 'Wolverine',
#  'year': 'Video',
#  'game_type': 'Action, Adventure, Drama            \n|\nAnnounced',
#  'rate': '',
#  'votes': ''}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=451&ref_=adv_nxt')
# Out:
# {'Name': "Lego Marvel's Avengers",
#  'year': '2016',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '7.9',
#  'votes': '1127'}

# %%
vedioGamePages = pd.DataFrame(Vgame_list) #transpose
vedioGamePages
# Out:
#                                  Name  year                   game_type rate  \
# 0    Marvel's Guardians of the Galaxy  2021   Action, Adventure, Comedy  9.1
# 1              Red Dead Redemption II  2018    Action, Adventure, Crime  9.7
# 2       Grand Theft Auto: San Andreas  2004               Action, Crime  9.4
# 3                  Grand Theft Auto V  2013        Action, Crime, Drama  9.5
# 4                      Cyberpunk 2077  2020        Action, Crime, Drama  7.9
# ..                                ...   ...                         ...  ...
# 495                     The Long Dark  2014   Adventure, Drama, Mystery  8.1
# 496                            Inside  2016  Adventure, Horror, Mystery  8.8
# 497      Lego Batman 3: Beyond Gotham  2014   Action, Adventure, Comedy  7.6
# 498               Fainaru fantajî XII  2006    Action, Adventure, Crime  8.2
# 499            Lego Marvel's Avengers  2016  Action, Adventure, Fantasy  7.9
#
#      votes
# 0      949
# 1    28888
# 2    37749
# 3    55657
# 4     5948
# ..     ...
# 495    384
# 496   3054
# 497   1437
# 498   3271
# 499   1127
#
# [500 rows x 5 columns]

# %%
vedioGamePages.to_csv('videogame_webscraping.csv')

# %%
vedioGamePages.Name=vedioGamePages.Name.str.lower()
vedioGamePages.head()
# Out:
#                                Name  year                  game_type rate  \
# 0  marvel's guardians of the galaxy  2021  Action, Adventure, Comedy  9.1
# 1            red dead redemption ii  2018   Action, Adventure, Crime  9.7
# 2     grand theft auto: san andreas  2004              Action, Crime  9.4
# 3                grand theft auto v  2013       Action, Crime, Drama  9.5
# 4                    cyberpunk 2077  2020       Action, Crime, Drama  7.9
#
#    votes
# 0    949
# 1  28888
# 2  37749
# 3  55657
# 4   5948

# %%
vedioGamePages
# Out:
#                                  Name  year                   game_type rate  \
# 0    marvel's guardians of the galaxy  2021   Action, Adventure, Comedy  9.1
# 1              red dead redemption ii  2018    Action, Adventure, Crime  9.7
# 2       grand theft auto: san andreas  2004               Action, Crime  9.4
# 3                  grand theft auto v  2013        Action, Crime, Drama  9.5
# 4                      cyberpunk 2077  2020        Action, Crime, Drama  7.9
# ..                                ...   ...                         ...  ...
# 495                     the long dark  2014   Adventure, Drama, Mystery  8.1
# 496                            inside  2016  Adventure, Horror, Mystery  8.8
# 497      lego batman 3: beyond gotham  2014   Action, Adventure, Comedy  7.6
# 498               fainaru fantajî xii  2006    Action, Adventure, Crime  8.2
# 499            lego marvel's avengers  2016  Action, Adventure, Fantasy  7.9
#
#      votes
# 0      949
# 1    28888
# 2    37749
# 3    55657
# 4     5948
# ..     ...
# 495    384
# 496   3054
# 497   1437
# 498   3271
# 499   1127
#
# [500 rows x 5 columns]

# %%
df=pd.read_csv('vgsales.csv') #data from kaggle

# %%
df.Name=df.Name.str.lower()
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                wii sports      Wii  2006.0        Sports  Nintendo
# 1     2         super mario bros.      NES  1985.0      Platform  Nintendo
# 2     3            mario kart wii      Wii  2008.0        Racing  Nintendo
# 3     4         wii sports resort      Wii  2009.0        Sports  Nintendo
# 4     5  pokemon red/pokemon blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.drop([ 'Year', 'Genre','Publisher'], axis=1, inplace=True)

# %% [markdown]
# # <a name=merge>Merging Data</a>

# %%
mer_vidgame=vedioGamePages.merge(df, on='Name')

# %%
mer_vidgame.head()
# Out:
#                             Name  year             game_type rate  votes  \
# 0  grand theft auto: san andreas  2004         Action, Crime  9.4  37749
# 1  grand theft auto: san andreas  2004         Action, Crime  9.4  37749
# 2  grand theft auto: san andreas  2004         Action, Crime  9.4  37749
# 3  grand theft auto: san andreas  2004         Action, Crime  9.4  37749
# 4             grand theft auto v  2013  Action, Crime, Drama  9.5  55657
#
#    Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0    18      PS2      9.43      0.40      0.41        10.57         20.81
# 1   875       XB      1.26      0.61      0.00         0.09          1.95
# 2  2122       PC      0.00      0.92      0.00         0.05          0.98
# 3  9829     X360      0.08      0.03      0.00         0.01          0.12
# 4    17      PS3      7.01      9.27      0.97         4.14         21.40

# %%
df1=pd.DataFrame(mer_vidgame)

# %% [markdown]
# # <a name=EDA>Explratory data analysis(EDA)</a>

# %%
df1.shape
# Out:
# (647, 12)

# %%
df1['game_type'].tolist()
# Out:
# ['Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Horror, Mystery, Thriller',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nAction, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'banned\n|\n\nAction, Adventure, Crime',
#  'banned\n|\n\nAction, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Mystery',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'banned\n|\n\nAction, Crime, Drama',
#  'banned\n|\n\nAction, Crime, Drama',
#  'Action, Sci-Fi, War',
#  'Action, Sci-Fi, War',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Action, Adventure, Crime            \n|\nAnnounced',
#  'Action, Adventure, Crime            \n|\nAnnounced',
#  'Action, Adventure, Crime            \n|\nAnnounced',
#  'Action, Adventure, Crime            \n|\nAnnounced',
#  'Action, Adventure, Crime            \n|\nAnnounced',
#  'Action, Adventure, Crime            \n|\nAnnounced',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Adventure, Comedy, Sci-Fi',
#  'Adventure, Comedy, Sci-Fi',
#  'Adventure, Comedy, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nCrime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Comedy, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Comedy, Horror',
#  'Action, Comedy, Horror',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Action, Horror, Mystery',
#  'Action, Horror, Mystery',
#  'Action, Crime, Thriller',
#  'Action, Crime, Thriller',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Drama, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Adventure, Fantasy',
#  'Action',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Thriller',
#  '130 min\n|\n\nAction, Adventure, Thriller',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'R18\n|\n\nCrime, Horror, Thriller',
#  'R18\n|\n\nCrime, Horror, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Action, Sci-Fi, War',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Drama, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Sci-Fi, Thriller',
#  'Action, Sci-Fi, Thriller',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Adventure, Mystery, Thriller',
#  'Adventure, Mystery, Thriller',
#  'Action, Crime, Drama',
#  'Action, Crime, Thriller',
#  'Action, Sci-Fi, War',
#  'Action, Sci-Fi, War',
#  'Action, Crime, Sci-Fi',
#  'Action, Drama, Mystery',
#  'Action, Drama, Mystery',
#  'Action, Drama, Mystery',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Adventure, Mystery',
#  'Adventure, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Animation, Action, Comedy',
#  'Animation, Action, Comedy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Crime, Mystery',
#  'Crime, Mystery',
#  'Crime, Mystery',
#  'Crime, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Crime, Thriller',
#  'Action, Crime, Thriller',
#  'Action, Crime, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nHorror, Mystery, Thriller',
#  'banned\n|\n\nHorror, Mystery, Thriller',
#  'banned\n|\n\nHorror, Mystery, Thriller',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Fantasy, Sci-Fi',
#  'Action, Fantasy, Sci-Fi',
#  'Action, Crime, Thriller',
#  'Action, Crime, Thriller',
#  'Adventure',
#  'Action, War',
#  'Action, War',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy']

# %%
df1['game_type']=df1['game_type'].str.replace('banned\n|\n\n','')
df1['game_type']=df1['game_type'].str.replace('\n|\nAnnounced','')
df1['game_type']=df1['game_type'].str.replace('|','')
df1['game_type']=df1['game_type'].str.replace('Announced','')
df1['game_type']=df1['game_type'].str.replace('130 min\n|\n\n','')
# Out:
# <ipython-input-28-439f93edc8ac>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('banned\n|\n\n','')
# <ipython-input-28-439f93edc8ac>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('\n|\nAnnounced','')
# <ipython-input-28-439f93edc8ac>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['game_type']=df1['game_type'].str.replace('|','')
# <ipython-input-28-439f93edc8ac>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('130 min\n|\n\n','')

# %%
df1
# Out:
#                               Name  year                   game_type rate  \
# 0    grand theft auto: san andreas  2004               Action, Crime  9.4
# 1    grand theft auto: san andreas  2004               Action, Crime  9.4
# 2    grand theft auto: san andreas  2004               Action, Crime  9.4
# 3    grand theft auto: san andreas  2004               Action, Crime  9.4
# 4               grand theft auto v  2013        Action, Crime, Drama  9.5
# ..                             ...   ...                         ...  ...
# 642         lego marvel's avengers  2016  Action, Adventure, Fantasy  7.9
# 643         lego marvel's avengers  2016  Action, Adventure, Fantasy  7.9
# 644         lego marvel's avengers  2016  Action, Adventure, Fantasy  7.9
# 645         lego marvel's avengers  2016  Action, Adventure, Fantasy  7.9
# 646         lego marvel's avengers  2016  Action, Adventure, Fantasy  7.9
#
#      votes  Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0    37749    18      PS2      9.43      0.40      0.41        10.57
# 1    37749   875       XB      1.26      0.61      0.00         0.09
# 2    37749  2122       PC      0.00      0.92      0.00         0.05
# 3    37749  9829     X360      0.08      0.03      0.00         0.01
# 4    55657    17      PS3      7.01      9.27      0.97         4.14
# ..     ...   ...      ...       ...       ...       ...          ...
# 642   1127  5597     XOne      0.18      0.11      0.00         0.03
# 643   1127  5698      PS3      0.10      0.17      0.00         0.05
# 644   1127  6957     WiiU      0.12      0.09      0.00         0.02
# 645   1127  6974      PSV      0.07      0.11      0.00         0.05
# 646   1127  8065      3DS      0.07      0.08      0.01         0.01
#
#      Global_Sales
# 0           20.81
# 1            1.95
# 2            0.98
# 3            0.12
# 4           21.40
# ..            ...
# 642          0.32
# 643          0.32
# 644          0.23
# 645          0.23
# 646          0.18
#
# [647 rows x 12 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 647 entries, 0 to 646
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          647 non-null    object
#  1   year          647 non-null    object
#  2   game_type     647 non-null    object
#  3   rate          647 non-null    object
#  4   votes         647 non-null    object
#  5   Rank          647 non-null    int64
#  6   Platform      647 non-null    object
#  7   NA_Sales      647 non-null    float64
#  8   EU_Sales      647 non-null    float64
#  9   JP_Sales      647 non-null    float64
#  10  Other_Sales   647 non-null    float64
#  11  Global_Sales  647 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 65.7+ KB

# %%
df1['year'] = pd.to_numeric(df1['year'], errors='coerce')

# %%
df1['rate'] = pd.to_numeric(df1['rate'], errors='coerce')

# %%
df1['votes'] = pd.to_numeric(df1['votes'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 647 entries, 0 to 646
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          647 non-null    object
#  1   year          641 non-null    float64
#  2   game_type     647 non-null    object
#  3   rate          641 non-null    float64
#  4   votes         641 non-null    float64
#  5   Rank          647 non-null    int64
#  6   Platform      647 non-null    object
#  7   NA_Sales      647 non-null    float64
#  8   EU_Sales      647 non-null    float64
#  9   JP_Sales      647 non-null    float64
#  10  Other_Sales   647 non-null    float64
#  11  Global_Sales  647 non-null    float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 65.7+ KB

# %%
df1.describe()
# Out:
#               year        rate         votes          Rank    NA_Sales  \
# count   641.000000  641.000000    641.000000    647.000000  647.000000
# mean   2010.051482    8.198908   7827.794072   3850.709428    0.977187
# std       4.743301    0.761812   8464.622520   3980.215834    1.510633
# min    1993.000000    4.400000     76.000000     17.000000    0.000000
# 25%    2007.000000    7.700000   2363.000000    721.500000    0.130000
# 50%    2011.000000    8.200000   5142.000000   2390.000000    0.420000
# 75%    2013.000000    8.700000   9790.000000   5681.000000    1.135000
# max    2023.000000    9.700000  55858.000000  16375.000000    9.670000
#
#          EU_Sales    JP_Sales  Other_Sales  Global_Sales
# count  647.000000  647.000000   647.000000    647.000000
# mean     0.642736    0.053756     0.233091      1.906986
# std      0.967026    0.160178     0.546981      2.800818
# min      0.000000    0.000000     0.000000      0.010000
# 25%      0.080000    0.000000     0.020000      0.320000
# 50%      0.290000    0.000000     0.080000      0.870000
# 75%      0.800000    0.040000     0.245000      2.235000
# max      9.270000    2.020000    10.570000     21.400000

# %%
df1
# Out:
#                               Name    year                   game_type  rate  \
# 0    grand theft auto: san andreas  2004.0               Action, Crime   9.4
# 1    grand theft auto: san andreas  2004.0               Action, Crime   9.4
# 2    grand theft auto: san andreas  2004.0               Action, Crime   9.4
# 3    grand theft auto: san andreas  2004.0               Action, Crime   9.4
# 4               grand theft auto v  2013.0        Action, Crime, Drama   9.5
# ..                             ...     ...                         ...   ...
# 642         lego marvel's avengers  2016.0  Action, Adventure, Fantasy   7.9
# 643         lego marvel's avengers  2016.0  Action, Adventure, Fantasy   7.9
# 644         lego marvel's avengers  2016.0  Action, Adventure, Fantasy   7.9
# 645         lego marvel's avengers  2016.0  Action, Adventure, Fantasy   7.9
# 646         lego marvel's avengers  2016.0  Action, Adventure, Fantasy   7.9
#
#        votes  Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0    37749.0    18      PS2      9.43      0.40      0.41        10.57
# 1    37749.0   875       XB      1.26      0.61      0.00         0.09
# 2    37749.0  2122       PC      0.00      0.92      0.00         0.05
# 3    37749.0  9829     X360      0.08      0.03      0.00         0.01
# 4    55657.0    17      PS3      7.01      9.27      0.97         4.14
# ..       ...   ...      ...       ...       ...       ...          ...
# 642   1127.0  5597     XOne      0.18      0.11      0.00         0.03
# 643   1127.0  5698      PS3      0.10      0.17      0.00         0.05
# 644   1127.0  6957     WiiU      0.12      0.09      0.00         0.02
# 645   1127.0  6974      PSV      0.07      0.11      0.00         0.05
# 646   1127.0  8065      3DS      0.07      0.08      0.01         0.01
#
#      Global_Sales
# 0           20.81
# 1            1.95
# 2            0.98
# 3            0.12
# 4           21.40
# ..            ...
# 642          0.32
# 643          0.32
# 644          0.23
# 645          0.23
# 646          0.18
#
# [647 rows x 12 columns]

# %%
df_transformed =pd.DataFrame()

df_transformed["NA_Sales_log"] = np.log(df1["NA_Sales"]) 
df_transformed["EU_Sales_log"] = np.log(df1["EU_Sales"]) 
df_transformed["JP_Sales_log"] = np.log(df1["JP_Sales"]) 
df_transformed["Other_Sales_log"] = np.log(df1["Other_Sales"])
df_transformed[["rank", "rate"]] = df1[["Rank", "rate"]]
df_transformed["Gobal_Sales_log"] = np.log(df1["Global_Sales"])
# Out:
# C:\Users\Hrlt2\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_transformed.head()
# Out:
#    NA_Sales_log  EU_Sales_log  JP_Sales_log  Other_Sales_log  rank  rate  \
# 0      2.243896     -0.916291     -0.891598         2.358020    18   9.4
# 1      0.231112     -0.494296          -inf        -2.407946   875   9.4
# 2          -inf     -0.083382          -inf        -2.995732  2122   9.4
# 3     -2.525729     -3.506558          -inf        -4.605170  9829   9.4
# 4      1.947338      2.226783     -0.030459         1.420696    17   9.5
#
#    Gobal_Sales_log
# 0         3.035434
# 1         0.667829
# 2        -0.020203
# 3        -2.120264
# 4         3.063391

# %%
df_transformed.to_csv("log_transformed_data.csv", sep = ",")

# %%
df_transformed.corr()
# Out:
#                  NA_Sales_log  EU_Sales_log  JP_Sales_log  Other_Sales_log  \
# NA_Sales_log         1.000000      0.681405      0.378179         0.754538
# EU_Sales_log         0.681405      1.000000      0.453435         0.854941
# JP_Sales_log         0.378179      0.453435      1.000000         0.513463
# Other_Sales_log      0.754538      0.854941      0.513463         1.000000
# rank                -0.848198     -0.815060     -0.246880        -0.827257
# rate                 0.195715      0.214056      0.298290         0.259650
# Gobal_Sales_log      0.911807      0.881984      0.425985         0.908834
#
#                      rank      rate  Gobal_Sales_log
# NA_Sales_log    -0.848198  0.195715         0.911807
# EU_Sales_log    -0.815060  0.214056         0.881984
# JP_Sales_log    -0.246880  0.298290         0.425985
# Other_Sales_log -0.827257  0.259650         0.908834
# rank             1.000000 -0.134883        -0.950138
# rate            -0.134883  1.000000         0.187205
# Gobal_Sales_log -0.950138  0.187205         1.000000
